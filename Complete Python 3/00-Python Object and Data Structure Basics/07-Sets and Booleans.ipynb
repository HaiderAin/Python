# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Set and Booleans
#
# There are two other object types in Python that we should quickly cover: Sets and Booleans.
#
# ## Sets
#
# Sets are an unordered collection of *unique* elements. We can construct them by using the set() function. Let's go ahead and make a set to see how it works

# %%
x = set()

# %%
# We add to sets with the add() method
x.add(1)

# %%
#Show
x
# Out:
# {1}

# %%
x.add(2)

# %%
x
# Out:
# {1, 2}

# %%
x
# Out:
# {1, 2}

# %%
x
# Out:
# {1, 2}

# %%
x.add(2)

# %%
#it will still show 1,2 as the output because the last addition was 2 which already exists in the set
x
# Out:
# {1, 2}

# %%
x2={1,2,2,3,3,1,7,8,3}

# %%
#the output will only contain the unique values
x2
# Out:
# {1, 2, 3, 7, 8}

# %%
x2
# Out:
# {1, 2, 3, 7, 8}

# %%
x2
# Out:
# {1, 2, 3, 7, 8}

# %%
x3={1, 2, 3, 7, 8,'rahul',1.34,4,True}

# %%
x3
# Out:
# {1, 1.34, 2, 3, 4, 7, 8, 'rahul'}

# %%
x3
# Out:
# {1, 1.34, 2, 3, 4, 7, 8, 'rahul'}

# %%
x4={True, 1.34, 2, 3, 4, 7, 8, 'rahul',False}

# %%
x4
# Out:
# {1.34, 2, 3, 4, 7, 8, False, True, 'rahul'}

# %% [markdown]
# very important to observe that (example Below) when 0 and 1 are used in the set along with True and False then only 0 and 1  are shown and not True or False.
# This is bacause Python internally considers True==1 and False==0 , and these will be dublicates, so removed.

# %%
x5={0,1,1.34, 2, 3, 4, 7, 8, False, True, 'rahul'}

# %%
x5
# Out:
# {0, 1, 1.34, 2, 3, 4, 7, 8, 'rahul'}

# %%
x5
# Out:
# {0, 1, 1.34, 2, 3, 4, 7, 8, 'rahul'}

# %%
x1=set()

# %%
x1.add(3)

# %%
x1
# Out:
# {3}

# %%
x1.add(4)

# %%
x1
# Out:
# {3, 4}

# %%
x1.add(3)

# %%
x1
# Out:
# {3, 4}

# %% [markdown]
# # Note the curly brackets. This does not indicate a dictionary! Although you can draw analogies as a set being a dictionary with only keys.
#
# We know that a set has only unique entries. So what happens when we try to add something that is already in a set?

# %%
# Add a different element
x.add(2)

# %%
#Show
x
# Out:
# {1, 2}

# %%
# Try to add the same element
x.add(1)

# %%
#Show
x
# Out:
# {1, 2}

# %% [markdown]
# Notice how it won't place another 1 there. That's because a set is only concerned with unique elements! We can cast a list with multiple repeat elements to a set to get the unique elements. For example:

# %%
# Create a list with repeats
list1 = [1,1,2,2,3,4,5,6,1,1]

# %%
list2=[1,1,2,3,3,4,5,56,56,6,66,6,56,56]

# %% [markdown]
# changing the List to a Set to get the unique values

# %%
set(list2)
# Out:
# {1, 2, 3, 4, 5, 6, 56, 66}

# %%
#notice that the casting didn't change the original list
list2
# Out:
# [1, 1, 2, 3, 3, 4, 5, 56, 56, 6, 66, 6, 56, 56]

# %%
# Cast as set to get unique values
set(list1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ## Booleans
#
# Python  comes with Booleans (with predefined True and False displays that are basically just the integers 1 and 0). It also has a placeholder object called None. Let's walk through a few quick examples of Booleans (we will dive deeper into them later in this course).

# %%
# Set object to be a boolean
a = True

# %%
#Show
a
# Out:
# True

# %% [markdown]
# We can also use comparison operators to create booleans. We will go over all the comparison operators later on in the course.

# %%
# Output is boolean
1 > 2
# Out:
# False

# %% [markdown]
# We can use None as a placeholder for an object that we don't want to reassign yet:

# %%
# None placeholder
b = None

# %%
# Show
print(b)
# Out:
# None

# %% [markdown]
# Thats it! You should now have a basic understanding of Python objects and data structure types. Next, go ahead and do the assessment test!
